# %%
import pandas as pd

# %%
df= pd.read_csv("E:\\DATA ANALYTICS ENGINEERING MASTERY COURSE\\PANDAS MATERIAL\\cardata.csv")

# %%
df.head(4)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0

# %%
df.shape
# Out:
# (432, 15)

# %%
df.size
# Out:
# 6480

# %%
df.index
# Out:
# RangeIndex(start=0, stop=432, step=1)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  $36,945   $33,337          3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0

# %% [markdown]
# # Change data type of MSRP and INVOICE from object to numerical

# %%
df['MSRP']=df['MSRP'].str.replace('$','')

# %%
df['MSRP']=df['MSRP'].str.replace(',','')

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain     MSRP   Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  36,945   $33,337          3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
df['Invoice']=df['Invoice'].str.replace('$,','')

# %%
df['Invoice']=df['Invoice'].str.replace(',','')

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain    MSRP Invoice  EngineSize  Cylinders  \
# 0  Acura   MDX  SUV   Asia        All  36945   33337          3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df['Invoice']=pd.to_numeric(df['Invoice'])

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain    MSRP  Invoice  EngineSize  Cylinders  \
# 0  Acura   MDX  SUV   Asia        All  36945   33337.0         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice        float64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df['MSRP']=pd.to_numeric(df['MSRP'])

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP           float64
# Invoice        float64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain     MSRP  Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  36945.0  33337.0         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0

# %% [markdown]
# # Find All Null Values in Dataset.if there is any null then fill it with mean of that column ?

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 62

# %% [markdown]
# # Percentage of null values in dataset ?

# %%
df.isnull().sum()*100/len(df)
# Out:
# Make           0.925926
# Model          0.925926
# Type           0.925926
# Origin         0.925926
# DriveTrain     0.925926
# MSRP           0.925926
# Invoice        0.925926
# EngineSize     0.925926
# Cylinders      0.000000
# Horsepower     0.925926
# MPG_City       0.925926
# MPG_Highway    0.925926
# Weight         0.925926
# Wheelbase      0.925926
# Length         0.925926
# dtype: float64

# %%
df['Cylinders'].fillna(df['Cylinders'].mean,inplace=True)

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain     MSRP  Invoice  EngineSize Cylinders  \
# 0  Acura   MDX  SUV   Asia        All  36945.0  33337.0         3.5         6
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0       265.0      17.0         23.0  4451.0      106.0   189.0

# %% [markdown]
# # Check what different types of MAKE on dataset?

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Volvo            12
# Jaguar           12
# Mazda            11
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mercury           9
# Suzuki            8
# Saturn            8
# Infiniti          8
# Cadillac          8
# GMC               8
# Acura             7
# Saab              7
# Porsche           7
# Land Rover        3
# Jeep              3
# Oldsmobile        3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# # Show all the records where origin is asia or europe?

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain     MSRP  Invoice  EngineSize Cylinders  \
# 0  Acura   MDX  SUV   Asia        All  36945.0  33337.0         3.5         6
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# ..     ...                      ...    ...     ...        ...      ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 430  Volvo                      V40  Wagon  Europe      Front  26135.0
# 431  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %% [markdown]
# # Remove all the records where weight is greater than 4000?

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain     MSRP  Invoice  EngineSize Cylinders  \
# 0  Acura   MDX  SUV   Asia        All  36945.0  33337.0         3.5         6
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
df[~(df['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  46100.0
# ..     ...                      ...    ...     ...        ...      ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 430  Volvo                      V40  Wagon  Europe      Front  26135.0
# 431  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %% [markdown]
# # Increase all the values of 'MPG_CITY' by 3.

# %%
df['MPG_City']+3
# Out:
# 0      20.0
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 432, dtype: float64

# %% [markdown]
# # Find Duplicated Values ?

# %%
df[df.duplicated()]
# Out:
#     Make Model Type Origin DriveTrain  MSRP  Invoice  EngineSize  \
# 39   NaN   NaN  NaN    NaN        NaN   NaN      NaN         NaN
# 161  NaN   NaN  NaN    NaN        NaN   NaN      NaN         NaN
# 173  NaN   NaN  NaN    NaN        NaN   NaN      NaN         NaN
#
#                                              Cylinders  Horsepower  MPG_City  \
# 39   <bound method Series.mean of 0      6\n1      ...         NaN       NaN
# 161  <bound method Series.mean of 0      6\n1      ...         NaN       NaN
# 173  <bound method Series.mean of 0      6\n1      ...         NaN       NaN
#
#      MPG_Highway  Weight  Wheelbase  Length
# 39           NaN     NaN        NaN     NaN
# 161          NaN     NaN        NaN     NaN
# 173          NaN     NaN        NaN     NaN

# %% [markdown]
# # Remove duplicates Records ?

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Type, Origin, DriveTrain, MSRP, Invoice, EngineSize, Cylinders, Horsepower, MPG_City, MPG_Highway, Weight, Wheelbase, Length]
# Index: []
